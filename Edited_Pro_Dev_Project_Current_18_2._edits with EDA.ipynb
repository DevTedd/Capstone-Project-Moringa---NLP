# %% [markdown]
# <a href="https://colab.research.google.com/github/DevTedd/Capstone-Project-Moringa---NLP/blob/main/Edited_Pro_Dev_Project_Current_18_2._edits%20with%20EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Proffesional Development : Capstone Project
#
# Team Members
#
#
#
# 1.   Kevin Kilonzo
#
# 2.   Rachel Juman
#
# 3.   Farnadis Kanja
#
# 4.   Ted Kiamni

# %% [markdown]
# # Problem Statement
#
# With the help of this dataset, one can understand more about human sentiments and also analyse the situation when a particular person intends to make use of hatred/racist comments

# %% [markdown]
# # Main Objective
#
# **The creation of a model that can identify hateful tweets**

# %% [markdown]
# # Business Understanding
#
# Social media, twitter in particular, has now become an integral part of how news is delivered. The demand for information continues to grow as has the sources of this news and thus creating a need for news classification. Using machine learning, news can be classified, therefore, enabling the user to access information that is interesting to them quickly and efficiently.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
import warnings
import re
import string
from wordcloud import WordCloud
warnings.filterwarnings('ignore')

# %%
train = pd.read_csv("/content/train_tweet.csv")
test = pd.read_csv("/content/test_tweets.csv")

# %%
train.head(10)
# Out:
#    id  label                                              tweet
# 0   1      0   @user when a father is dysfunctional and is s...
# 1   2      0  @user @user thanks for #lyft credit i can't us...
# 2   3      0                                bihday your majesty
# 3   4      0  #model   i love u take with u all the time in ...
# 4   5      0             factsguide: society now    #motivation
# 5   6      0  [2/2] huge fan fare and big talking before the...
# 6   7      0   @user camping tomorrow @user @user @user @use...
# 7   8      0  the next school year is the year for exams.ð...
# 8   9      0  we won!!! love the land!!! #allin #cavs #champ...
# 9  10      0   @user @user welcome here !  i'm   it's so #gr...

# %%
test.head(10)
# Out:
#       id                                              tweet
# 0  31963  #studiolife #aislife #requires #passion #dedic...
# 1  31964   @user #white #supremacists want everyone to s...
# 2  31965  safe ways to heal your #acne!!    #altwaystohe...
# 3  31966  is the hp and the cursed child book up for res...
# 4  31967    3rd #bihday to my amazing, hilarious #nephew...
# 5  31968                        choose to be   :) #momtips
# 6  31969  something inside me dies ð¦ð¿â¨  eyes nes...
# 7  31970  #finished#tattoo#inked#ink#loveitâ¤ï¸ #â¤ï¸...
# 8  31971   @user @user @user i will never understand why...
# 9  31972  #delicious   #food #lovelife #capetown mannaep...

# %%
train.shape
# Out:
# (31962, 3)

# %%
test.shape
# Out:
# (17197, 2)

# %%
train.dtypes
# Out:
# id        int64
# label     int64
# tweet    object
# dtype: object

# %%
#Lets see how the hateful and non-hateful comments are distributed
train['label'].unique()
# Out:
# array([0, 1])

# %% [markdown]
# # Data Cleaning

# %%
df = train
df.head(2)
# Out:
#    id  label                                              tweet
# 0   1      0   @user when a father is dysfunctional and is s...
# 1   2      0  @user @user thanks for #lyft credit i can't us...

# %%
#Removing links 
df["clean_tweets"] = df["tweet"].apply(lambda s: ' '.join(re.sub("(w+://S+)", " ", s).split()))
df[['tweet','clean_tweets']].iloc[9]
# Out:
# tweet            @user @user welcome here !  i'm   it's so #gr...
# clean_tweets        @user @user welcome here ! i'm it's so #gr8 !
# Name: 9, dtype: object

# %%
#Changing all the letter to lower case
df['clean_tweets'] = df.tweet.map(lambda x: x.lower())
train.head()
# Out:
#    id  ...                                       clean_tweets
# 0   1  ...   @user when a father is dysfunctional and is s...
# 1   2  ...  @user @user thanks for #lyft credit i can't us...
# 2   3  ...                                bihday your majesty
# 3   4  ...  #model   i love u take with u all the time in ...
# 4   5  ...             factsguide: society now    #motivation
#
# [5 rows x 4 columns]

# %%
#Removing the punctuation
df['clean_tweets'] = df['clean_tweets'].apply(lambda x: re.sub('[%s]' % re.escape(string.punctuation), '' , x))
df['clean_tweets'] = df['clean_tweets'].str.replace('user','')
df['clean_tweets']
# Out:
# 0          when a father is dysfunctional and is so sel...
# 1          thanks for lyft credit i cant use cause they...
# 2                                      bihday your majesty
# 3        model   i love u take with u all the time in u...
# 4                     factsguide society now    motivation
#                                ...
# 31957    ate  isz that youuuððððððð...
# 31958      to see nina turner on the airwaves trying to...
# 31959    listening to sad songs on a monday morning otw...
# 31960     sikh temple vandalised in in calgary wso cond...
# 31961                          thank you  for you follow
# Name: clean_tweets, Length: 31962, dtype: object

# %%
df.tail(12)
# Out:
#           id  ...                                       clean_tweets
# 31950  31951  ...    you can try to tail us to stop butt were jus...
# 31951  31952  ...  ive just posted a new blog secondlife lonely n...
# 31952  31953  ...                           you went too far with
# 31953  31954  ...  good morning instagram shower water berlin ber...
# 31954  31955  ...  holiday   bull up you will dominate your bull ...
# 31955  31956  ...  less than 2 weeks ð
# ðð¼ð¹ððµ  ib...
# 31956  31957  ...  off fishing tomorrow  carnt wait first time in...
# 31957  31958  ...  ate  isz that youuuððððððð...
# 31958  31959  ...    to see nina turner on the airwaves trying to...
# 31959  31960  ...  listening to sad songs on a monday morning otw...
# 31960  31961  ...   sikh temple vandalised in in calgary wso cond...
# 31961  31962  ...                        thank you  for you follow
#
# [12 rows x 4 columns]

# %% [markdown]
# # Removing emojis

# %%
df.head(12)
# Out:
#     id  ...                                       clean_tweets
# 0    1  ...    when a father is dysfunctional and is so sel...
# 1    2  ...    thanks for lyft credit i cant use cause they...
# 2    3  ...                                bihday your majesty
# 3    4  ...  model   i love u take with u all the time in u...
# 4    5  ...               factsguide society now    motivation
# 5    6  ...  22 huge fan fare and big talking before they l...
# 6    7  ...                   camping tomorrow        dannyâ¦
# 7    8  ...  the next school year is the year for examsð¯...
# 8    9  ...  we won love the land allin cavs champions clev...
# 9   10  ...                   welcome here   im   its so gr8
# 10  11  ...   â ireland consumer price index mom climbed ...
# 11  12  ...  we are so selfish orlando standwithorlando pul...
#
# [12 rows x 4 columns]

# %%
def deEmojify(inputString):
    return inputString.encode('ascii', 'ignore').decode('ascii')
df["clean_tweets"] = df["clean_tweets"].apply(lambda s: deEmojify(s))
df.head(12)
# Out:
#     id  ...                                       clean_tweets
# 0    1  ...    when a father is dysfunctional and is so sel...
# 1    2  ...    thanks for lyft credit i cant use cause they...
# 2    3  ...                                bihday your majesty
# 3    4  ...  model   i love u take with u all the time in u...
# 4    5  ...               factsguide society now    motivation
# 5    6  ...  22 huge fan fare and big talking before they l...
# 6    7  ...                      camping tomorrow        danny
# 7    8  ...  the next school year is the year for exams can...
# 8    9  ...  we won love the land allin cavs champions clev...
# 9   10  ...                   welcome here   im   its so gr8
# 10  11  ...    ireland consumer price index mom climbed fro...
# 11  12  ...  we are so selfish orlando standwithorlando pul...
#
# [12 rows x 4 columns]

# %% [markdown]
# # Tokenization

# %%
df.head(12)
# Out:
#     id  ...                                       clean_tweets
# 0    1  ...    when a father is dysfunctional and is so sel...
# 1    2  ...    thanks for lyft credit i cant use cause they...
# 2    3  ...                                bihday your majesty
# 3    4  ...  model   i love u take with u all the time in u...
# 4    5  ...               factsguide society now    motivation
# 5    6  ...  22 huge fan fare and big talking before they l...
# 6    7  ...                      camping tomorrow        danny
# 7    8  ...  the next school year is the year for exams can...
# 8    9  ...  we won love the land allin cavs champions clev...
# 9   10  ...                   welcome here   im   its so gr8
# 10  11  ...    ireland consumer price index mom climbed fro...
# 11  12  ...  we are so selfish orlando standwithorlando pul...
#
# [12 rows x 4 columns]

# %% [markdown]
# # Begin Tokenization

# %%
#Removing the word user 
import spacy 
#This library is quite popular now and NLP practitioners use this to get their work done in the best way.
#loading the english language small model of spacy
en = spacy.load('en_core_web_sm')
sw_spacy = en.Defaults.stop_words
print(sw_spacy)
# Out:
# {'four', '’ll', 'a', 'last', 'move', 'first', 'herein', 'others', 'your', 'next', '’d', 'someone', 'various', 'besides', 'its', 'more', 'side', '’m', 'him', 'however', 'is', 'amongst', 'ourselves', 'seem', 'since', 'whereupon', 'give', 'regarding', 'make', 'had', 'now', 'about', 'several', 're', 'six', 'hers', 'say', 'get', 'thereafter', 'together', 'else', 'from', 'doing', 'down', 'whence', 'his', 'within', 'before', 'though', 'yet', 'for', 'something', 'their', 'when', 'may', 'afterwards', 'take', 'be', 'has', 'whereas', 'keep', 'much', 'seems', 'ten', "'re", 'it', 'part', 'done', 'latterly', 'here', 'such', 'sometime', 'on', 'behind', 'often', 'but', 'itself', 'wherever', 'front', 'sometimes', 'made', 'call', 'bottom', 'over', 'somewhere', 'out', 'all', '‘ve', 'some', 'mine', 'so', 'moreover', 'whom', 'beforehand', 'less', 'by', 'themselves', 'those', 'i', 'seeming', "'ve", 'through', 'hereupon', 'once', 'same', 'namely', 'only', 'hereby', 'somehow', 'one', 'does', 'becomes', 'along', 'toward', 'amount', 'put', '‘d', 'name', 'across', 'own', 'under', 'whose', 'no', 'back', 'used', 'fifteen', 'beside', 'anyway', 'unless', 'which', 'during', 'five', 'almost', 'the', 'other', 'serious', 'every', 'yourself', 'are', 'well', 'never', 'nevertheless', 'not', 'none', 'becoming', 'that', 'indeed', 'therein', 'around', 'her', 'sixty', 'who', 'me', 'up', 'throughout', 'nine', 'he', 'being', "'ll", 'whatever', 'noone', 'show', 'again', 'although', 'few', 'everywhere', 'we', 'yourselves', 'our', 'as', 'at', 'two', 'of', 'below', 'himself', 'will', 'perhaps', 'you', 'neither', 'quite', 'therefore', 'too', 'top', 'might', 'formerly', 'become', 'nor', 'whoever', 'each', 'still', 'three', '‘ll', 'everything', 'then', 'really', 'cannot', 'anyhow', 'hence', 'full', 'whether', 'must', 'n’t', '‘s', 'enough', 'can', 'herself', 'became', 'except', 'twelve', 'eleven', 'nobody', 'ever', 'why', 'thus', 'meanwhile', 'an', 'after', 'wherein', 'n‘t', 'both', 'my', 'above', 'onto', 'please', 'via', 'nowhere', 'already', 'even', '’ve', 'whenever', 'among', 'these', 'most', '’re', 'than', '‘m', 'us', 'hundred', 'if', 'whereafter', 'thereby', 'latter', 'using', 'anything', 'how', 'whither', 'go', 'third', 'fifty', 'further', 'either', 'thence', 'any', '’s', 'ours', 'whole', 'could', 'former', 'have', 'anywhere', 'without', 'been', 'between', 'ca', 'see', 'with', 'another', 'just', "'s", 'thru', 'should', 'anyone', 'rather', 'per', 'this', 'or', 'where', 'nothing', 'were', 'to', 'forty', 'in', 'whereby', 'beyond', 'also', 'very', 'mostly', "'m", 'least', 'there', 'because', 'them', 'yours', 'always', 'she', 'many', 'against', 'off', 'twenty', "n't", 'until', '‘re', 'was', 'otherwise', 'while', 'eight', 'myself', 'into', 'everyone', 'alone', 'would', 'what', 'seemed', 'empty', 'thereupon', 'am', 'they', 'hereafter', 'upon', "'d", 'do', 'towards', 'elsewhere', 'due', 'did', 'and'}

# %%
# We will also download and import nlkt which is a tokenizer. 
# This library will help us break (messages) into individual linguistic units i.e. words.
#
# Applying the tokenization
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
sw_nltk = stopwords.words('english')
print(sw_nltk)
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# to remove stop words
df['clean_tweets'] = df['clean_tweets'].apply(lambda x: ' '.join([word for word in x.split() if word not in (sw_nltk)]))

# %%
#tweets_space = [tweet for word in df.split() if word.lower() not in sw_spacy]
df.head(10)
# Out:
#    id  ...                                       clean_tweets
# 0   1  ...  father dysfunctional selfish drags kids dysfun...
# 1   2  ...  thanks lyft credit cant use cause dont offer w...
# 2   3  ...                                     bihday majesty
# 3   4  ...                        model love u take u time ur
# 4   5  ...                      factsguide society motivation
# 5   6  ...  22 huge fan fare big talking leave chaos pay d...
# 6   7  ...                             camping tomorrow danny
# 7   8  ...  next school year year exams cant think school ...
# 8   9  ...  love land allin cavs champions cleveland cleve...
# 9  10  ...                                     welcome im gr8
#
# [10 rows x 4 columns]

# %%
df.head(50)
# Out:
#     id  ...                                       clean_tweets
# 0    1  ...  father dysfunctional selfish drags kids dysfun...
# 1    2  ...  thanks lyft credit cant use cause dont offer w...
# 2    3  ...                                     bihday majesty
# 3    4  ...                        model love u take u time ur
# 4    5  ...                      factsguide society motivation
# 5    6  ...  22 huge fan fare big talking leave chaos pay d...
# 6    7  ...                             camping tomorrow danny
# 7    8  ...  next school year year exams cant think school ...
# 8    9  ...  love land allin cavs champions cleveland cleve...
# 9   10  ...                                     welcome im gr8
# 10  11  ...  ireland consumer price index mom climbed previ...
# 11  12  ...  selfish orlando standwithorlando pulseshooting...
# 12  13  ...              get see daddy today 80days gettingfed
# 13  14  ...  cnn calls michigan middle school build wall ch...
# 14  15  ...  comment australia opkillingbay seashepherd hel...
# 15  16  ...            ouchjunior angrygot7 junior yugyoem omg
# 16  17  ...                   thankful paner thankful positive
# 17  18  ...                                      retweet agree
# 18  19  ...    friday smiles around via ig cookies make people
# 19  20  ...                 know essential oils made chemicals
# 20  21  ...  euro2016 people blaming ha conceded goal fat r...
# 21  22  ...  sad little dude badday coneofshame cats pissed...
# 22  23  ...  product day happy man wine tool whos weekend t...
# 23  24  ...                             lumpy says prove lumpy
# 24  25  ...        tgif ff gamedev indiedev indiegamedev squad
# 25  26  ...  beautiful sign vendor 80 4500 upsideofflorida ...
# 26  27  ...  smiles media pressconference antalya turkey su...
# 27  28  ...     great panel mediatization public service ica16
# 28  29  ...                                  happy fathers day
# 29  30  ...  50 people went nightclub good night 1 mans act...
# 30  31  ...  never chance vote presidential candidate excit...
# 31  32  ...      alohafriday time exist positivevibes hawaiian
# 32  33  ...  rip fellow nohern ireland fan sadley passed aw...
# 33  34  ...  hard monday due cloudy weather disabling oxyge...
# 34  35  ...  unbelievable 21st century wed need something l...
# 35  36  ...  taylorswift1989 bull dominate bull direct what...
# 36  37  ...             morning travelingram dalat ripinkylife
# 37  38  ...  one word tells photoshop enoughisenough dontph...
# 38  39  ...  oh cedarpoint waited 2 hours valravn line stop...
# 39  40  ...                thankful sunshine thankful positive
# 40  41  ...  finally finish book youve working awhile bookw...
# 41  42  ...  yup knicks fan hard easier nba fan playoffs ro...
# 42  43  ...                 life social networking embrace day
# 43  44  ...         mom shares bihday bihday snake see weekend
# 44  45  ...  lovely echeveria bloomsflowers grow gardening ...
# 45  46  ...                   amazing iam positive affirmation
# 46  47  ...                        model love u take u time ur
# 47  48  ...                   whenever im something goes wrong
# 48  49  ...                          feeling blue illustration
# 49  50  ...                               best pa life knowing
#
# [50 rows x 4 columns]

# %% [markdown]
# # Exploratory Data Analysis

# %%
# EDA dataframe
df_eda = df.copy()
df_eda.head()
# Out:
#    id  ...                                       clean_tweets
# 0   1  ...  father dysfunctional selfish drags kids dysfun...
# 1   2  ...  thanks lyft credit cant use cause dont offer w...
# 2   3  ...                                     bihday majesty
# 3   4  ...                        model love u take u time ur
# 4   5  ...                      factsguide society motivation
#
# [5 rows x 4 columns]

# %% [markdown]
# ## Univariate

# %%
# Count plot of label column(0-Non hateful, 1-hateful)
sb.countplot(df_eda['label'])

# %%
# Most commom words
from collections import Counter

# %%
df_eda["clean_tweets"] =df_eda["clean_tweets"].apply(lambda x:str(x).split())
top = Counter([item for sublist in df["clean_tweets"] for item in sublist])
temp = pd.DataFrame(top.most_common(20))
temp.columns = ['Common_words','count']
temp.style.background_gradient(cmap='Greens')
# Out:
# <style type="text/css">
# #T_f97a7_row0_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_f97a7_row1_col1 {
#   background-color: #208843;
#   color: #f1f1f1;
# }
# #T_f97a7_row2_col1 {
#   background-color: #7dc87e;
#   color: #000000;
# }
# #T_f97a7_row3_col1 {
#   background-color: #8ed08b;
#   color: #000000;
# }
# #T_f97a7_row4_col1 {
#   background-color: #d3eecd;
#   color: #000000;
# }
# #T_f97a7_row5_col1 {
#   background-color: #d4eece;
#   color: #000000;
# }
# #T_f97a7_row6_col1 {
#   background-color: #d6efd0;
#   color: #000000;
# }
# #T_f97a7_row7_col1 {
#   background-color: #d7efd1;
#   color: #000000;
# }
# #T_f97a7_row8_col1 {
#   background-color: #dff3da;
#   color: #000000;
# }
# #T_f97a7_row9_col1 {
#   background-color: #e5f5e0;
#   color: #000000;
# }
# #T_f97a7_row10_col1 {
#   background-color: #e7f6e2;
#   color: #000000;
# }
# #T_f97a7_row11_col1, #T_f97a7_row12_col1 {
#   background-color: #ebf7e7;
#   color: #000000;
# }
# #T_f97a7_row13_col1 {
#   background-color: #ecf8e8;
#   color: #000000;
# }
# #T_f97a7_row14_col1 {
#   background-color: #f0f9ec;
#   color: #000000;
# }
# #T_f97a7_row15_col1 {
#   background-color: #f0f9ed;
#   color: #000000;
# }
# #T_f97a7_row16_col1 {
#   background-color: #f1faee;
#   color: #000000;
# }
# #T_f97a7_row17_col1 {
#   background-color: #f3faf0;
#   color: #000000;
# }
# #T_f97a7_row18_col1 {
#   background-color: #f5fbf3;
#   color: #000000;
# }
# #T_f97a7_row19_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_f97a7_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Common_words</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f97a7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f97a7_row0_col0" class="data row0 col0" >love</td>
#       <td id="T_f97a7_row0_col1" class="data row0 col1" >2725</td>
#     </tr>
#     <tr>
#       <th id="T_f97a7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f97a7_row1_col0" class="data row1 col0" >day</td>
#       <td id="T_f97a7_row1_col1" class="data row1 col1" >2256</td>
#     </tr>
#     <tr>
#       <th id="T_f97a7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f97a7_row2_col0" class="data row2 col0" >happy</td>
#       <td id="T_f97a7_row2_col1" class="data row2 col1" >1691</td>
#     </tr>
#     <tr>
#       <th id="T_f97a7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f97a7_row3_col0" class="data row3 col0" >amp</td>
#       <td id="T_f97a7_row3_col1" class="data row3 col1" >1602</td>
#     </tr>
#     <tr>
#       <th id="T_f97a7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f97a7_row4_col0" class="data row4 col0" >im</td>
#       <td id="T_f97a7_row4_col1" class="data row4 col1" >1157</td>
#     </tr>
#     <tr>
#       <th id="T_f97a7_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f97a7_row5_col0" class="data row5 col0" >u</td>
#       <td id="T_f97a7_row5_col1" class="data row5 col1" >1143</td>
#     </tr>
#     <tr>
#       <th id="T_f97a7_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f97a7_row6_col0" class="data row6 col0" >life</td>
#       <td id="T_f97a7_row6_col1" class="data row6 col1" >1127</td>
#     </tr>
#     <tr>
#       <th id="T_f97a7_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f97a7_row7_col0" class="data row7 col0" >time</td>
#       <td id="T_f97a7_row7_col1" class="data row7 col1" >1125</td>
#     </tr>
#     <tr>
#       <th id="T_f97a7_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f97a7_row8_col0" class="data row8 col0" >like</td>
#       <td id="T_f97a7_row8_col1" class="data row8 col1" >1052</td>
#     </tr>
#     <tr>
#       <th id="T_f97a7_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f97a7_row9_col0" class="data row9 col0" >today</td>
#       <td id="T_f97a7_row9_col1" class="data row9 col1" >1005</td>
#     </tr>
#     <tr>
#       <th id="T_f97a7_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_f97a7_row10_col0" class="data row10 col0" >new</td>
#       <td id="T_f97a7_row10_col1" class="data row10 col1" >987</td>
#     </tr>
#     <tr>
#       <th id="T_f97a7_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_f97a7_row11_col0" class="data row11 col0" >positive</td>
#       <td id="T_f97a7_row11_col1" class="data row11 col1" >934</td>
#     </tr>
#     <tr>
#       <th id="T_f97a7_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_f97a7_row12_col0" class="data row12 col0" >thankful</td>
#       <td id="T_f97a7_row12_col1" class="data row12 col1" >925</td>
#     </tr>
#     <tr>
#       <th id="T_f97a7_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_f97a7_row13_col0" class="data row13 col0" >get</td>
#       <td id="T_f97a7_row13_col1" class="data row13 col1" >919</td>
#     </tr>
#     <tr>
#       <th id="T_f97a7_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_f97a7_row14_col0" class="data row14 col0" >people</td>
#       <td id="T_f97a7_row14_col1" class="data row14 col1" >865</td>
#     </tr>
#     <tr>
#       <th id="T_f97a7_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_f97a7_row15_col0" class="data row15 col0" >bihday</td>
#       <td id="T_f97a7_row15_col1" class="data row15 col1" >855</td>
#     </tr>
#     <tr>
#       <th id="T_f97a7_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_f97a7_row16_col0" class="data row16 col0" >good</td>
#       <td id="T_f97a7_row16_col1" class="data row16 col1" >850</td>
#     </tr>
#     <tr>
#       <th id="T_f97a7_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_f97a7_row17_col0" class="data row17 col0" >cant</td>
#       <td id="T_f97a7_row17_col1" class="data row17 col1" >813</td>
#     </tr>
#     <tr>
#       <th id="T_f97a7_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_f97a7_row18_col0" class="data row18 col0" >one</td>
#       <td id="T_f97a7_row18_col1" class="data row18 col1" >783</td>
#     </tr>
#     <tr>
#       <th id="T_f97a7_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_f97a7_row19_col0" class="data row19 col0" >see</td>
#       <td id="T_f97a7_row19_col1" class="data row19 col1" >758</td>
#     </tr>
#   </tbody>
# </table>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from plotly import graph_objs as go
import plotly.express as px
import plotly.figure_factory as ff

# %%
fig = px.bar(temp, x="count", y="Common_words", title='Commmon Words in Selected Text', orientation='h', 
             width=700, height=700,color='Common_words')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="d2400dae-1f00-41bb-8944-0d0d4e65e8d9" class="plotly-graph-div" style="height:700px; width:700px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d2400dae-1f00-41bb-8944-0d0d4e65e8d9")) {                    Plotly.newPlot(                        "d2400dae-1f00-41bb-8944-0d0d4e65e8d9",                        [{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"love","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"love","offsetgroup":"love","orientation":"h","showlegend":true,"textposition":"auto","x":[2725],"xaxis":"x","y":["love"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"day","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"day","offsetgroup":"day","orientation":"h","showlegend":true,"textposition":"auto","x":[2256],"xaxis":"x","y":["day"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"happy","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"happy","offsetgroup":"happy","orientation":"h","showlegend":true,"textposition":"auto","x":[1691],"xaxis":"x","y":["happy"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"amp","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"amp","offsetgroup":"amp","orientation":"h","showlegend":true,"textposition":"auto","x":[1602],"xaxis":"x","y":["amp"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"im","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"im","offsetgroup":"im","orientation":"h","showlegend":true,"textposition":"auto","x":[1157],"xaxis":"x","y":["im"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"u","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"u","offsetgroup":"u","orientation":"h","showlegend":true,"textposition":"auto","x":[1143],"xaxis":"x","y":["u"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"life","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"life","offsetgroup":"life","orientation":"h","showlegend":true,"textposition":"auto","x":[1127],"xaxis":"x","y":["life"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"time","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"time","offsetgroup":"time","orientation":"h","showlegend":true,"textposition":"auto","x":[1125],"xaxis":"x","y":["time"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"like","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"like","offsetgroup":"like","orientation":"h","showlegend":true,"textposition":"auto","x":[1052],"xaxis":"x","y":["like"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"today","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"today","offsetgroup":"today","orientation":"h","showlegend":true,"textposition":"auto","x":[1005],"xaxis":"x","y":["today"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"new","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"new","offsetgroup":"new","orientation":"h","showlegend":true,"textposition":"auto","x":[987],"xaxis":"x","y":["new"],"yaxi ...

# %%
fig = px.treemap(temp, path=['Common_words'], values='count',title='Tree of Most Common Words')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="75c7c620-51c1-4f75-acc7-cdd8892de3ae" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("75c7c620-51c1-4f75-acc7-cdd8892de3ae")) {                    Plotly.newPlot(                        "75c7c620-51c1-4f75-acc7-cdd8892de3ae",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>count=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["amp","bihday","cant","day","get","good","happy","im","life","like","love","new","one","people","positive","see","thankful","time","today","u"],"labels":["amp","bihday","cant","day","get","good","happy","im","life","like","love","new","one","people","positive","see","thankful","time","today","u"],"name":"","parents":["","","","","","","","","","","","","","","","","","","",""],"values":[1602,855,813,2256,919,850,1691,1157,1127,1052,2725,987,783,865,934,758,925,1125,1005,1143],"type":"treemap"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d ...

# %%
from wordcloud import WordCloud

text = df_eda['clean_tweets'].values

wordcloud = WordCloud().generate(str(text))

plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %% [markdown]
# ## Bivariate

# %%
#Selecting the negative tweets
negative_tweets = df_eda[df_eda['label']== 1]
negative_tweets.head()
# Out:
#     id  ...                                       clean_tweets
# 13  14  ...  [cnn, calls, michigan, middle, school, build, ...
# 14  15  ...  [comment, australia, opkillingbay, seashepherd...
# 17  18  ...                                   [retweet, agree]
# 23  24  ...                        [lumpy, says, prove, lumpy]
# 34  35  ...  [unbelievable, 21st, century, wed, need, somet...
#
# [5 rows x 4 columns]

# %%
top = Counter([item for sublist in negative_tweets["clean_tweets"] for item in sublist])
temp_negative = pd.DataFrame(top.most_common(20))
temp_negative.columns = ['Common_words','count']
temp_negative.style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_1f3a8_row0_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_1f3a8_row1_col1 {
#   background-color: #f03f2e;
#   color: #f1f1f1;
# }
# #T_1f3a8_row2_col1 {
#   background-color: #fc8e6e;
#   color: #000000;
# }
# #T_1f3a8_row3_col1 {
#   background-color: #fc9d7f;
#   color: #000000;
# }
# #T_1f3a8_row4_col1 {
#   background-color: #fc9e80;
#   color: #000000;
# }
# #T_1f3a8_row5_col1 {
#   background-color: #fca98c;
#   color: #000000;
# }
# #T_1f3a8_row6_col1 {
#   background-color: #fdd1be;
#   color: #000000;
# }
# #T_1f3a8_row7_col1 {
#   background-color: #fed9c9;
#   color: #000000;
# }
# #T_1f3a8_row8_col1 {
#   background-color: #fedbcc;
#   color: #000000;
# }
# #T_1f3a8_row9_col1 {
#   background-color: #fee0d2;
#   color: #000000;
# }
# #T_1f3a8_row10_col1 {
#   background-color: #fee7dc;
#   color: #000000;
# }
# #T_1f3a8_row11_col1 {
#   background-color: #ffebe2;
#   color: #000000;
# }
# #T_1f3a8_row12_col1 {
#   background-color: #ffeee6;
#   color: #000000;
# }
# #T_1f3a8_row13_col1 {
#   background-color: #ffefe8;
#   color: #000000;
# }
# #T_1f3a8_row14_col1 {
#   background-color: #fff0e8;
#   color: #000000;
# }
# #T_1f3a8_row15_col1 {
#   background-color: #fff2ec;
#   color: #000000;
# }
# #T_1f3a8_row16_col1, #T_1f3a8_row17_col1 {
#   background-color: #fff3ed;
#   color: #000000;
# }
# #T_1f3a8_row18_col1 {
#   background-color: #fff4ee;
#   color: #000000;
# }
# #T_1f3a8_row19_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_1f3a8_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Common_words</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1f3a8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1f3a8_row0_col0" class="data row0 col0" >amp</td>
#       <td id="T_1f3a8_row0_col1" class="data row0 col1" >283</td>
#     </tr>
#     <tr>
#       <th id="T_1f3a8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1f3a8_row1_col0" class="data row1 col0" >trump</td>
#       <td id="T_1f3a8_row1_col1" class="data row1 col1" >199</td>
#     </tr>
#     <tr>
#       <th id="T_1f3a8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1f3a8_row2_col0" class="data row2 col0" >libtard</td>
#       <td id="T_1f3a8_row2_col1" class="data row2 col1" >149</td>
#     </tr>
#     <tr>
#       <th id="T_1f3a8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1f3a8_row3_col0" class="data row3 col0" >like</td>
#       <td id="T_1f3a8_row3_col1" class="data row3 col1" >139</td>
#     </tr>
#     <tr>
#       <th id="T_1f3a8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1f3a8_row4_col0" class="data row4 col0" >white</td>
#       <td id="T_1f3a8_row4_col1" class="data row4 col1" >138</td>
#     </tr>
#     <tr>
#       <th id="T_1f3a8_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_1f3a8_row5_col0" class="data row5 col0" >black</td>
#       <td id="T_1f3a8_row5_col1" class="data row5 col1" >131</td>
#     </tr>
#     <tr>
#       <th id="T_1f3a8_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_1f3a8_row6_col0" class="data row6 col0" >racist</td>
#       <td id="T_1f3a8_row6_col1" class="data row6 col1" >103</td>
#     </tr>
#     <tr>
#       <th id="T_1f3a8_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_1f3a8_row7_col0" class="data row7 col0" >politics</td>
#       <td id="T_1f3a8_row7_col1" class="data row7 col1" >97</td>
#     </tr>
#     <tr>
#       <th id="T_1f3a8_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_1f3a8_row8_col0" class="data row8 col0" >people</td>
#       <td id="T_1f3a8_row8_col1" class="data row8 col1" >95</td>
#     </tr>
#     <tr>
#       <th id="T_1f3a8_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_1f3a8_row9_col0" class="data row9 col0" >allahsoil</td>
#       <td id="T_1f3a8_row9_col1" class="data row9 col1" >92</td>
#     </tr>
#     <tr>
#       <th id="T_1f3a8_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_1f3a8_row10_col0" class="data row10 col0" >liberal</td>
#       <td id="T_1f3a8_row10_col1" class="data row10 col1" >82</td>
#     </tr>
#     <tr>
#       <th id="T_1f3a8_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_1f3a8_row11_col0" class="data row11 col0" >might</td>
#       <td id="T_1f3a8_row11_col1" class="data row11 col1" >77</td>
#     </tr>
#     <tr>
#       <th id="T_1f3a8_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_1f3a8_row12_col0" class="data row12 col0" >sjw</td>
#       <td id="T_1f3a8_row12_col1" class="data row12 col1" >74</td>
#     </tr>
#     <tr>
#       <th id="T_1f3a8_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_1f3a8_row13_col0" class="data row13 col0" >women</td>
#       <td id="T_1f3a8_row13_col1" class="data row13 col1" >72</td>
#     </tr>
#     <tr>
#       <th id="T_1f3a8_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_1f3a8_row14_col0" class="data row14 col0" >new</td>
#       <td id="T_1f3a8_row14_col1" class="data row14 col1" >71</td>
#     </tr>
#     <tr>
#       <th id="T_1f3a8_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_1f3a8_row15_col0" class="data row15 col0" >obama</td>
#       <td id="T_1f3a8_row15_col1" class="data row15 col1" >68</td>
#     </tr>
#     <tr>
#       <th id="T_1f3a8_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_1f3a8_row16_col0" class="data row16 col0" >retweet</td>
#       <td id="T_1f3a8_row16_col1" class="data row16 col1" >67</td>
#     </tr>
#     <tr>
#       <th id="T_1f3a8_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_1f3a8_row17_col0" class="data row17 col0" >dont</td>
#       <td id="T_1f3a8_row17_col1" class="data row17 col1" >67</td>
#     </tr>
#     <tr>
#       <th id="T_1f3a8_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_1f3a8_row18_col0" class="data row18 col0" >hate</td>
#       <td id="T_1f3a8_row18_col1" class="data row18 col1" >66</td>
#     </tr>
#     <tr>
#       <th id="T_1f3a8_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_1f3a8_row19_col0" class="data row19 col0" >racism</td>
#       <td id="T_1f3a8_row19_col1" class="data row19 col1" >64</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig = px.bar(temp_negative, x="count", y="Common_words", title='Most Commmon Negative Words', orientation='h', 
             width=700, height=700,color='Common_words')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="5a29c629-df2c-47be-b0e3-8236113e4e5a" class="plotly-graph-div" style="height:700px; width:700px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5a29c629-df2c-47be-b0e3-8236113e4e5a")) {                    Plotly.newPlot(                        "5a29c629-df2c-47be-b0e3-8236113e4e5a",                        [{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"amp","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"amp","offsetgroup":"amp","orientation":"h","showlegend":true,"textposition":"auto","x":[283],"xaxis":"x","y":["amp"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"trump","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"trump","offsetgroup":"trump","orientation":"h","showlegend":true,"textposition":"auto","x":[199],"xaxis":"x","y":["trump"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"libtard","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"libtard","offsetgroup":"libtard","orientation":"h","showlegend":true,"textposition":"auto","x":[149],"xaxis":"x","y":["libtard"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"like","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"like","offsetgroup":"like","orientation":"h","showlegend":true,"textposition":"auto","x":[139],"xaxis":"x","y":["like"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"white","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"white","offsetgroup":"white","orientation":"h","showlegend":true,"textposition":"auto","x":[138],"xaxis":"x","y":["white"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"black","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"black","offsetgroup":"black","orientation":"h","showlegend":true,"textposition":"auto","x":[131],"xaxis":"x","y":["black"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"racist","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"racist","offsetgroup":"racist","orientation":"h","showlegend":true,"textposition":"auto","x":[103],"xaxis":"x","y":["racist"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"politics","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"politics","offsetgroup":"politics","orientation":"h","showlegend":true,"textposition":"auto","x":[97],"xaxis":"x","y":["politics"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"people","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"people","offsetgroup":"people","orientation":"h","showlegend":true,"textposition":"auto","x":[95],"xaxis":"x","y":["people"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"allahsoil","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"allahsoil","offsetgroup":"allahsoil","orientation":"h","showlegend":true,"textposition":"auto","x":[92],"xaxis":"x","y":["allahsoil"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"liberal","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"liberal","offsetgroup":"liberal","orien ...

# %%
fig = px.treemap(temp_negative, path=['Common_words'], values='count',title='Tree Of Most Common Negative Words')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="f3287c67-6b5b-4dc2-965e-af61f4bfd820" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f3287c67-6b5b-4dc2-965e-af61f4bfd820")) {                    Plotly.newPlot(                        "f3287c67-6b5b-4dc2-965e-af61f4bfd820",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>count=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["allahsoil","amp","black","dont","hate","liberal","libtard","like","might","new","obama","people","politics","racism","racist","retweet","sjw","trump","white","women"],"labels":["allahsoil","amp","black","dont","hate","liberal","libtard","like","might","new","obama","people","politics","racism","racist","retweet","sjw","trump","white","women"],"name":"","parents":["","","","","","","","","","","","","","","","","","","",""],"values":[92,283,131,67,66,82,149,139,77,71,68,95,97,64,103,67,74,199,138,72],"type":"treemap"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f9 ...

# %%
#Selecting the negative tweets
positive_tweets = df_eda[df_eda['label']== 0]
positive_tweets.head()
# Out:
#    id  ...                                       clean_tweets
# 0   1  ...  [father, dysfunctional, selfish, drags, kids, ...
# 1   2  ...  [thanks, lyft, credit, cant, use, cause, dont,...
# 2   3  ...                                  [bihday, majesty]
# 3   4  ...                [model, love, u, take, u, time, ur]
# 4   5  ...                  [factsguide, society, motivation]
#
# [5 rows x 4 columns]

# %%
top = Counter([item for sublist in positive_tweets["clean_tweets"] for item in sublist])
temp_positive = pd.DataFrame(top.most_common(20))
temp_positive.columns = ['Common_words','count']
temp_positive.style.background_gradient(cmap='Greens')
# Out:
# <style type="text/css">
# #T_ff25e_row0_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_ff25e_row1_col1 {
#   background-color: #1d8640;
#   color: #f1f1f1;
# }
# #T_ff25e_row2_col1 {
#   background-color: #7ac77b;
#   color: #000000;
# }
# #T_ff25e_row3_col1 {
#   background-color: #b8e3b2;
#   color: #000000;
# }
# #T_ff25e_row4_col1 {
#   background-color: #d4eece;
#   color: #000000;
# }
# #T_ff25e_row5_col1, #T_ff25e_row6_col1 {
#   background-color: #d5efcf;
#   color: #000000;
# }
# #T_ff25e_row7_col1 {
#   background-color: #d6efd0;
#   color: #000000;
# }
# #T_ff25e_row8_col1 {
#   background-color: #e4f5df;
#   color: #000000;
# }
# #T_ff25e_row9_col1, #T_ff25e_row10_col1 {
#   background-color: #e9f7e5;
#   color: #000000;
# }
# #T_ff25e_row11_col1, #T_ff25e_row12_col1 {
#   background-color: #eaf7e6;
#   color: #000000;
# }
# #T_ff25e_row13_col1 {
#   background-color: #ecf8e8;
#   color: #000000;
# }
# #T_ff25e_row14_col1 {
#   background-color: #eff9eb;
#   color: #000000;
# }
# #T_ff25e_row15_col1 {
#   background-color: #f1faee;
#   color: #000000;
# }
# #T_ff25e_row16_col1 {
#   background-color: #f4fbf2;
#   color: #000000;
# }
# #T_ff25e_row17_col1 {
#   background-color: #f5fbf2;
#   color: #000000;
# }
# #T_ff25e_row18_col1, #T_ff25e_row19_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_ff25e_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Common_words</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ff25e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ff25e_row0_col0" class="data row0 col0" >love</td>
#       <td id="T_ff25e_row0_col1" class="data row0 col1" >2699</td>
#     </tr>
#     <tr>
#       <th id="T_ff25e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ff25e_row1_col0" class="data row1 col0" >day</td>
#       <td id="T_ff25e_row1_col1" class="data row1 col1" >2248</td>
#     </tr>
#     <tr>
#       <th id="T_ff25e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ff25e_row2_col0" class="data row2 col0" >happy</td>
#       <td id="T_ff25e_row2_col1" class="data row2 col1" >1679</td>
#     </tr>
#     <tr>
#       <th id="T_ff25e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ff25e_row3_col0" class="data row3 col0" >amp</td>
#       <td id="T_ff25e_row3_col1" class="data row3 col1" >1319</td>
#     </tr>
#     <tr>
#       <th id="T_ff25e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ff25e_row4_col0" class="data row4 col0" >life</td>
#       <td id="T_ff25e_row4_col1" class="data row4 col1" >1121</td>
#     </tr>
#     <tr>
#       <th id="T_ff25e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ff25e_row5_col0" class="data row5 col0" >u</td>
#       <td id="T_ff25e_row5_col1" class="data row5 col1" >1116</td>
#     </tr>
#     <tr>
#       <th id="T_ff25e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ff25e_row6_col0" class="data row6 col0" >im</td>
#       <td id="T_ff25e_row6_col1" class="data row6 col1" >1112</td>
#     </tr>
#     <tr>
#       <th id="T_ff25e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ff25e_row7_col0" class="data row7 col0" >time</td>
#       <td id="T_ff25e_row7_col1" class="data row7 col1" >1103</td>
#     </tr>
#     <tr>
#       <th id="T_ff25e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_ff25e_row8_col0" class="data row8 col0" >today</td>
#       <td id="T_ff25e_row8_col1" class="data row8 col1" >993</td>
#     </tr>
#     <tr>
#       <th id="T_ff25e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_ff25e_row9_col0" class="data row9 col0" >positive</td>
#       <td id="T_ff25e_row9_col1" class="data row9 col1" >931</td>
#     </tr>
#     <tr>
#       <th id="T_ff25e_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_ff25e_row10_col0" class="data row10 col0" >thankful</td>
#       <td id="T_ff25e_row10_col1" class="data row10 col1" >925</td>
#     </tr>
#     <tr>
#       <th id="T_ff25e_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_ff25e_row11_col0" class="data row11 col0" >new</td>
#       <td id="T_ff25e_row11_col1" class="data row11 col1" >916</td>
#     </tr>
#     <tr>
#       <th id="T_ff25e_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_ff25e_row12_col0" class="data row12 col0" >like</td>
#       <td id="T_ff25e_row12_col1" class="data row12 col1" >913</td>
#     </tr>
#     <tr>
#       <th id="T_ff25e_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_ff25e_row13_col0" class="data row13 col0" >get</td>
#       <td id="T_ff25e_row13_col1" class="data row13 col1" >885</td>
#     </tr>
#     <tr>
#       <th id="T_ff25e_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_ff25e_row14_col0" class="data row14 col0" >bihday</td>
#       <td id="T_ff25e_row14_col1" class="data row14 col1" >855</td>
#     </tr>
#     <tr>
#       <th id="T_ff25e_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_ff25e_row15_col0" class="data row15 col0" >good</td>
#       <td id="T_ff25e_row15_col1" class="data row15 col1" >817</td>
#     </tr>
#     <tr>
#       <th id="T_ff25e_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_ff25e_row16_col0" class="data row16 col0" >cant</td>
#       <td id="T_ff25e_row16_col1" class="data row16 col1" >776</td>
#     </tr>
#     <tr>
#       <th id="T_ff25e_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_ff25e_row17_col0" class="data row17 col0" >people</td>
#       <td id="T_ff25e_row17_col1" class="data row17 col1" >770</td>
#     </tr>
#     <tr>
#       <th id="T_ff25e_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_ff25e_row18_col0" class="data row18 col0" >one</td>
#       <td id="T_ff25e_row18_col1" class="data row18 col1" >735</td>
#     </tr>
#     <tr>
#       <th id="T_ff25e_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_ff25e_row19_col0" class="data row19 col0" >see</td>
#       <td id="T_ff25e_row19_col1" class="data row19 col1" >733</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig = px.bar(temp_positive, x="count", y="Common_words", title='Most Commmon Positive Words', orientation='h', 
             width=700, height=700,color='Common_words')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="d6c88e31-300f-4ea1-a017-8d5424720fd3" class="plotly-graph-div" style="height:700px; width:700px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d6c88e31-300f-4ea1-a017-8d5424720fd3")) {                    Plotly.newPlot(                        "d6c88e31-300f-4ea1-a017-8d5424720fd3",                        [{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"love","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"love","offsetgroup":"love","orientation":"h","showlegend":true,"textposition":"auto","x":[2699],"xaxis":"x","y":["love"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"day","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"day","offsetgroup":"day","orientation":"h","showlegend":true,"textposition":"auto","x":[2248],"xaxis":"x","y":["day"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"happy","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"happy","offsetgroup":"happy","orientation":"h","showlegend":true,"textposition":"auto","x":[1679],"xaxis":"x","y":["happy"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"amp","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"amp","offsetgroup":"amp","orientation":"h","showlegend":true,"textposition":"auto","x":[1319],"xaxis":"x","y":["amp"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"life","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"life","offsetgroup":"life","orientation":"h","showlegend":true,"textposition":"auto","x":[1121],"xaxis":"x","y":["life"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"u","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"u","offsetgroup":"u","orientation":"h","showlegend":true,"textposition":"auto","x":[1116],"xaxis":"x","y":["u"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"im","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"im","offsetgroup":"im","orientation":"h","showlegend":true,"textposition":"auto","x":[1112],"xaxis":"x","y":["im"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"time","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"time","offsetgroup":"time","orientation":"h","showlegend":true,"textposition":"auto","x":[1103],"xaxis":"x","y":["time"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"today","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"today","offsetgroup":"today","orientation":"h","showlegend":true,"textposition":"auto","x":[993],"xaxis":"x","y":["today"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"positive","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"positive","offsetgroup":"positive","orientation":"h","showlegend":true,"textposition":"auto","x":[931],"xaxis":"x","y":["positive"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"thankful","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"thankful","offsetgroup":"thankful","orientation":"h","showlegend":true,"textposition":"auto","x":[925], ...

# %%
fig = px.treemap(temp_positive, path=['Common_words'], values='count',title='Tree Of Most Common Positive Words')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="ca58e31b-9b3c-45cf-b28d-5568ff3f948e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ca58e31b-9b3c-45cf-b28d-5568ff3f948e")) {                    Plotly.newPlot(                        "ca58e31b-9b3c-45cf-b28d-5568ff3f948e",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>count=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["amp","bihday","cant","day","get","good","happy","im","life","like","love","new","one","people","positive","see","thankful","time","today","u"],"labels":["amp","bihday","cant","day","get","good","happy","im","life","like","love","new","one","people","positive","see","thankful","time","today","u"],"name":"","parents":["","","","","","","","","","","","","","","","","","","",""],"values":[1319,855,776,2248,885,817,1679,1112,1121,913,2699,916,735,770,931,733,925,1103,993,1116],"type":"treemap"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dco ...
